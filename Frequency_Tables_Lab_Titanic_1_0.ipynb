# %% [markdown]
# <a href="https://colab.research.google.com/github/oliverow0/Skyline-Math-200/blob/main/Frequency_Tables_Lab_Titanic_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You will learn all about how to use Python to create frequency table
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
link = 'https://raw.githubusercontent.com/kmath22/kmath22/main/titanic_complete.csv'

titanic_df = pd.read_csv(link)

# %%
titanic_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
#View the column of survived

# %%
#What percent of people survived the titanic crash?
#Create a frequency table from the Survived column

# %%
#Create the same frequency table with percents using "normalize = True"

# %%
#What percent of people survived the titanic crash?
#Use round()

# %%
#What class are most passengers in?

# %%
#What port did most passenger embarked from?

# %%
#use .plot(kind = 'pie') to create a pie chart

# %%
pip install researchpy

# %%
import researchpy as rp

# %%
#Use researchpy to create a frequency table for survived

# %%
#Create a frequency for sex

# %% [markdown]
# Part 2:  Use the Diamond dataset to answer the questions in part 2

# %%
import pandas as pd

# %%
#Upload the diamond dataset in Github
# paste the url into the ''
link2 =''

diamond_df = pd.read_csv(link2)

# %%
#View the diamond_df dataset

# %%
#What percent of diamonds have the best cut?

# %%
#What clarity of a diamond is the least popular?

# %%
#What is the most popular color of diamonds?
