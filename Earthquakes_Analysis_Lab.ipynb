# %% [markdown]
# <a href="https://colab.research.google.com/github/oliverow0/Skyline-Math-200/blob/main/Earthquakes_Analysis_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Check out the link:https://rpubs.com/TheFlyingDutchman/earthquake

# %%
import pandas as pd

# %%
link ='https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/quakes.csv'

quakes = pd.read_csv(link)

quakes

# %%
quakes.info()

# %% [markdown]
# # ***Basic*** Visualizations of the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x = 'depth' , y ='mag', data = quakes)

# %%
#Scatterplot of Depth vs Stations

# %%
#Scatterplot of Mag vs Stations

# %%
quakes.corr()

# %%
sns.regplot(x = 'mag' , y ='stations', data = quakes)

# %%
#import libraries
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
Y = quakes['stations']
X = quakes['mag']
X = sm.add_constant(X)
reg = sm.OLS(Y,X).fit()
print (reg.summary() )

# %% [markdown]
# # **Bonus**
# Use plotly to view location data

# %%
import plotly.express as px

# %%
fig = px.scatter_mapbox(quakes,
                        lon = quakes['long'],
                        lat = quakes['lat'],
                        zoom = 5,
                        color =quakes['mag'] ,
                        size = quakes['stations'],
                        width = 1000,
                        height = 1000,
                        title = 'Earthquake Map',
                        )

fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(margin = {"r":0, "t":50})


fig.show()
